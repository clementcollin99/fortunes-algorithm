# %%
import numpy as np
import matplotlib.pyplot as plt

from src import Fortune

# %%
seeds = [
    [2.5, 2.5],
    [6, 2.4],
    [4, 7.5],
    [6, 8],
    [4, 4],
    [6, 3],
]
seeds = np.array(seeds)

# %%
fortune = Fortune(seeds)
fortune.launch()
